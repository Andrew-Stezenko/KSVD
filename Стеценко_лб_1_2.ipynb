# %% [markdown]
# Лабораторна робота 1.2
# Тема: "Візуалізація даних з використанням бібліотеки Seaborn"

# %% [markdown]
# Завдання 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("shopping_trends.csv")

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# Розмір таблиці

# %%
data.shape
# Out:
# (3900, 19)

# %% [markdown]
# Перевіряємо пропуски

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# Перевіряємо дублікати

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Типи стовпців

# %%
data.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %% [markdown]
# Перейменовуємо назви стовпців: Замінимо прописні букви на строчні
# (маленькі) та пробіл на підкреслення.

# %%
data.rename(columns=lambda x: x.lower().replace(' ', '_'), inplace=True)

# %%
data.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# Далі виконайте наступні завдання. Побудуйте графіки з використанням
# бібліотеки seaborn

# %% [markdown]
# 1. Гістограма віку (age):
# Побудуйте гістограму віку клієнтів, використовуючи Seaborn

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='age', bins=30, kde=True, color='purple')
plt.title('Гістограма віку клієнтів')
plt.xlabel('Вік')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# 2. Порівняння розподілу покупок за статтею (item_purchased):
# Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які
# товари покупають клієнти найчастіше.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data, y='item_purchased', palette='rocket', order=data['item_purchased'].value_counts().index)
plt.title('Розподіл покупок за статтею')
plt.xlabel('Частота покупок')
plt.ylabel('Стаття покупки')
plt.show()
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22040\1579448956.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, y='item_purchased', palette='rocket', order=data['item_purchased'].value_counts().index)

# %% [markdown]
# 3. Залежність між віком та сумою покупок (purchase_amount):
# Використовуйте scatter plot, щоб візуалізувати залежність між віком та
# сумою покупок

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='age', y='purchase_amount_(usd)', color='purple')
plt.title('Залежність між віком та сумою покупок')
plt.xlabel('Вік')
plt.ylabel('Сума покупок')
plt.show()

# %% [markdown]
# 4. Графік розподілу оцінок товарів (review_rating):
# Побудуйте графік розподілу оцінок товарів для оцінки якості.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='review_rating', bins=5, kde=True, color='purple')
plt.title('Графік розподілу оцінок товарів')
plt.xlabel('Оцінка товару')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# 5. Категоріальна діаграма для статі (gender):
# Створіть категоріальну діаграму, щоб відобразити розподіл покупок за
# статтею.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='gender', palette='rocket')
plt.title('Розподіл покупок за статтею')
plt.xlabel('Стать')
plt.ylabel('Частота')
plt.show()
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22040\734325168.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='gender', palette='rocket')

# %% [markdown]
# 6. Залежність між рейтингом і сумою покупок (review_rating і
# purchase_amount):
# Вивчіть, чи існує зв'язок між рейтингом товару і сумою покупок за
# допомогою scatter plot.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='review_rating', y='purchase_amount_(usd)', color='purple')
plt.title('Залежність між рейтингом і сумою покупок')
plt.xlabel('Рейтинг товару')
plt.ylabel('Сума покупок')
plt.show()

# %% [markdown]
# 7. Сезонність покупок (season):
# Побудуйте стовпчату діаграму, яка відображає, в який сезон клієнти
# роблять найбільше покупок.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='season', palette='rocket')
plt.title('Сезонність покупок')
plt.xlabel('Сезон')
plt.ylabel('Покупки')
plt.show()
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22040\621917590.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='season', palette='rocket')

# %% [markdown]
# 8. Графік розподілу розмірів одягу (size):
# Створіть графік розподілу розмірів одягу, щоб визначити популярність
# різних розмірів.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='size', palette='rocket')
plt.title('Розподіл розмірів одягу')
plt.xlabel('Розмір одягу')
plt.ylabel('Частота')
plt.show()
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22040\3723844516.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='size', palette='rocket')

# %% [markdown]
# 9. Кількість покупок відносно типу оплати (payment_method):
# Порівняйте, скільки покупок робиться за різними методами оплати за
# допомогою стовпчатої діаграми.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='payment_method', palette='rocket')
plt.title('Кількість покупок відносно типу оплати')
plt.xlabel('Метод оплати')
plt.ylabel('Кількість покупок')
plt.show()
# Out:
# C:\Users\Stetsenko\AppData\Local\Temp\ipykernel_22040\3685143268.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='payment_method', palette='rocket')

# %% [markdown]
# 10.Залежність між кількістю попередніх покупок (previous_purchases) і
# сумою поточної покупки (purchase_amount):
# Створіть scatter plot для визначення, чи існує зв'язок між кількістю
# попередніх покупок та сумою поточної покупки.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='previous_purchases', y='purchase_amount_(usd)', color='purple')
plt.title('Залежність між кількістю попередніх покупок та сумою поточної покупки')
plt.xlabel('Кількість попередніх покупок')
plt.ylabel('Сума поточної покупки')
plt.show()

# %% [markdown]
# Завдання 2
# Побудуйте графік поверхні (3D surface plot) для візуалізації залежності
# між трьома числовими змінними з використанням бібліотеки Seaborn.
# Налаштуйте відображення графіка, включаючи назву графіку, підписи
# осей і інші необхідні параметри для кращого розуміння візуалізації.
# Додайте кольорову легенду.
# 𝑧 = 𝑠𝑖𝑛 √𝑥
# 2 + 𝑦
# 2, 𝑥 ∈ [−5; 5], 𝑦 ∈ [−5; 5]

# %%
x = np.linspace(-5, 5)
y = np.linspace(-5, 5)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

plt.figure(figsize=(10, 6))
ax = plt.axes(projection='3d')
surf = ax.plot_surface(x, y, z, cmap='rocket', edgecolor='none')
ax.set_title('3D Surface Plot)')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z = sin(sqrt(x^2 + y^2))')
plt.colorbar(surf, ax=ax, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# Завдання 3
# Побудуйте графік теплової поверхні для візуалізації залежності між
# двома або більше числовими змінними на основі матриці даних,
# використовуючи бібліотеку Seaborn.

# %%
matrix = np.random.rand(10, 10)

plt.figure(figsize=(10, 8))
sns.heatmap(matrix, cmap='rocket', annot=True, fmt=".2f")
plt.title('Графік теплової поверхні')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
